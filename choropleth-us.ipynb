# %%
import matplotlib.pyplot as plt
import geopandas

states = geopandas.read_file('us-states.shp')
type(states)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
states.head()
# Out:
#   STATEFP   STATENS     AFFGEOID GEOID STUSPS                  NAME LSAD  \
# 0      06  01779778  0400000US06    06     CA            California   00
# 1      11  01702382  0400000US11    11     DC  District of Columbia   00
# 2      12  00294478  0400000US12    12     FL               Florida   00
# 3      13  01705317  0400000US13    13     GA               Georgia   00
# 4      16  01779783  0400000US16    16     ID                 Idaho   00
#
#           ALAND       AWATER     region  \
# 0  403483823181  20483271881       West
# 1     158350578     18633500  Northeast
# 2  138903200855  31407883551  Southeast
# 3  148963503399   4947080103  Southeast
# 4  214045425549   2397728105       West
#
#                                             geometry
# 0  MULTIPOLYGON Z (((-118.59397 33.46720 0.00000,...
# 1  POLYGON Z ((-77.11976 38.93434 0.00000, -77.04...
# 2  MULTIPOLYGON Z (((-81.81169 24.56874 0.00000, ...
# 3  POLYGON Z ((-85.60516 34.98468 0.00000, -85.47...
# ...

# %%
states.geometry
# Out:
# 0     MULTIPOLYGON Z (((-118.59397 33.46720 0.00000,...
# 1     POLYGON Z ((-77.11976 38.93434 0.00000, -77.04...
# 2     MULTIPOLYGON Z (((-81.81169 24.56874 0.00000, ...
# 3     POLYGON Z ((-85.60516 34.98468 0.00000, -85.47...
# 4     POLYGON Z ((-117.24303 44.39097 0.00000, -117....
# 5     POLYGON Z ((-91.50617 40.20064 0.00000, -91.49...
# 6     POLYGON Z ((-96.62187 42.77925 0.00000, -96.57...
# 7     POLYGON Z ((-89.54443 36.57451 0.00000, -89.47...
# 8     POLYGON Z ((-94.04305 32.69303 0.00000, -94.04...
# 9     MULTIPOLYGON Z (((-76.04621 38.02553 0.00000, ...
# 10    MULTIPOLYGON Z (((-84.61622 45.89447 0.00000, ...
# 11    POLYGON Z ((-97.22904 49.00069 0.00000, -96.93...
# 12    POLYGON Z ((-95.76564 40.58521 0.00000, -95.53...
# 13    MULTIPOLYGON Z (((-72.01893 41.27411 0.00000, ...
# 14    POLYGON Z ((-124.55244 42.84057 0.00000, -124....
# 15    POLYGON Z ((-90.30070 35.02879 0.00000, -90.26...
# 16    POLYGON Z ((-106.62345 31.91403 0.00000, -106....
# ...

# %%
states.plot()
# Out:
# <AxesSubplot:>

# %%
states.plot(cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
states.plot(column='ALAND', cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
states[states['NAME'] == 'Indiana'].plot()
# Out:
# <AxesSubplot:>

# %%
import pandas as pd

us_pop = pd.read_csv('us-pop.csv')
us_pop.set_index('state', inplace=True)
us_pop
# Out:
#        population
# state
# AL        4833722
# AK         735132
# AZ        6626624
# AR        2959373
# CA       38332521
# CO        5268367
# CT        3596080
# DE         925749
# FL       19552860
# GA        9992167
# HI        1404054
# ID        1612136
# IL       12882135
# IN        6570902
# IA        3090416
# KS        2893957
# KY        4395295
# LA        4625470
# ME        1328302
# MD        5928814
# MA        6692824
# MI        9895622
# MN        5420380
# MS        2991207
# MO        6044171
# MT        1015165
# NE        1868516
# NV        2790136
# NH        1323459
# NJ        8899339
# NM        2085287
# NY       19651127
# NC        9848060
# ND         723393
# OH       11570808
# OK        3850568
# OR        3930065
# PA       12773801
# RI        1051511
# SC        4774839
# SD         844877
# TN        6495978
# TX       26448193
# UT        2900872
# VT         626630
# VA        8260405
# WA        6971406
# WV        1854304
# ...

# %%
states = states.join(us_pop, 'STUSPS')
states.columns
# Out:
# Index(['STATEFP', 'STATENS', 'AFFGEOID', 'GEOID', 'STUSPS', 'NAME', 'LSAD',
#        'ALAND', 'AWATER', 'region', 'geometry', 'population'],
#       dtype='object')

# %%
states.plot(column='population')
# Out:
# <AxesSubplot:>

# %%
states['predictions'] = pd.Series([1,2,3])
states[['STUSPS', 'predictions']]
# Out:
#    STUSPS  predictions
# 0      CA          1.0
# 1      DC          2.0
# 2      FL          3.0
# 3      GA          NaN
# 4      ID          NaN
# 5      IL          NaN
# 6      IA          NaN
# 7      KY          NaN
# 8      LA          NaN
# 9      MD          NaN
# 10     MI          NaN
# 11     MN          NaN
# 12     MO          NaN
# 13     NY          NaN
# 14     OR          NaN
# 15     TN          NaN
# 16     TX          NaN
# 17     VA          NaN
# 18     WI          NaN
# 19     AZ          NaN
# 20     AR          NaN
# 21     CO          NaN
# 22     IN          NaN
# 23     CT          NaN
# 24     NE          NaN
# 25     NM          NaN
# 26     NC          NaN
# 27     OH          NaN
# 28     ME          NaN
# 29     MA          NaN
# 30     MS          NaN
# 31     MT          NaN
# 32     OK          NaN
# 33     SC          NaN
# 34     SD          NaN
# 35     UT          NaN
# 36     WA          NaN
# 37     WV          NaN
# 38     WY          NaN
# ...
